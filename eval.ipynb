# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import joblib
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_absolute_error

# %%
# Load your preprocessed DataFrame
df_final = pd.read_csv("/content/drive/MyDrive/SMAI_project/df_final.csv")

# %% [markdown]
# ### Random Forest Regressor

# %%
# Define features and target
X = df_final[["4s", "6s", "strike_rate", "BF", "year"]]
y = df_final["runs"]

# Split for evaluation
_, X_test, _, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Load saved model
model = joblib.load("/content/drive/MyDrive/SMAI_project/random_forest_model.pkl")

# Predict
y_pred = model.predict(X_test)

# Evaluate
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f"Evaluation Results:")
print(f"R2 Score(R2): {r2:.4f}")
print(f"Mean Squared Error(MSE): {mse:.2f}")
print(f"Mean Absolute Error(MAE): {mae:.2f}")

plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, color='blue', s=40, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel("Actual Runs")
plt.ylabel("Predicted Runs")
plt.title("Predicted vs Actual Runs (Random Forest Regressor)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Evaluation Results:
# R2 Score(R2): 0.9978
# Mean Squared Error(MSE): 0.83
# Mean Absolute Error(MAE): 0.12

# %% [markdown]
# ### Decision Tree Regressor

# %%
# Load the model
model = joblib.load("/content/drive/MyDrive/SMAI_project/decision_tree_model.pkl")

# Predict using the loaded model
y_pred = model.predict(X_test)

# Evaluate
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f"Evaluation Results:")
print(f"R2 Score(R2): {r2:.4f}")
print(f"Mean Squared Error(MSE): {mse:.2f}")
print(f"Mean Absolute Error(MAE): {mae:.2f}")

plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, color='blue', s=40, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel("Actual Runs")
plt.ylabel("Predicted Runs")
plt.title("Predicted vs Actual Runs (Random Forest Regressor)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Evaluation Results:
# R2 Score(R2): 0.9969
# Mean Squared Error(MSE): 1.19
# Mean Absolute Error(MAE): 0.20

# %% [markdown]
# ### Gradient Boosting Regressor

# %%
# Load trained model
model = joblib.load("/content/drive/MyDrive/SMAI_project/gradient_boosting_model.pkl")

# Predict and evaluate
y_pred = model.predict(X_test)

# Evaluate
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f"Evaluation Results:")
print(f"R2 Score(R2): {r2:.4f}")
print(f"Mean Squared Error(MSE): {mse:.2f}")
print(f"Mean Absolute Error(MAE): {mae:.2f}")

plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, color='blue', s=40, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel("Actual Runs")
plt.ylabel("Predicted Runs")
plt.title("Predicted vs Actual Runs (Gradient Boosting Regressor)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Evaluation Results:
# R2 Score(R2): 0.9960
# Mean Squared Error(MSE): 1.52
# Mean Absolute Error(MAE): 0.81

# %% [markdown]
# ### Ada Boosting Regressor

# %%
# Load trained model
model = joblib.load("/content/drive/MyDrive/SMAI_project/adaboost_model.pkl")

# Make predictions
y_pred = model.predict(X_test)

# Evaluate
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f"Evaluation Results:")
print(f"R2 Score(R2): {r2:.4f}")
print(f"Mean Squared Error(MSE): {mse:.2f}")
print(f"Mean Absolute Error(MAE): {mae:.2f}")

plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, color='blue', s=40, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel("Actual Runs")
plt.ylabel("Predicted Runs")
plt.title("Predicted vs Actual Runs (Gradient Boosting Regressor)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Evaluation Results:
# R2 Score(R2): 0.8595
# Mean Squared Error(MSE): 53.04
# Mean Absolute Error(MAE): 6.30

# %% [markdown]
# ### Gaussian Procress Regressor

# %%
# Load trained model
model = joblib.load("/content/drive/MyDrive/SMAI_project/gaussian_process_model.pkl")

# Predict
y_pred = model.predict(X_test)

# Evaluate
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f"Evaluation Results:")
print(f"R2 Score(R2): {r2:.4f}")
print(f"Mean Squared Error(MSE): {mse:.2f}")
print(f"Mean Absolute Error(MAE): {mae:.2f}")

plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, color='blue', s=40, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel("Actual Runs")
plt.ylabel("Predicted Runs")
plt.title("Predicted vs Actual Runs (Gaussian Process Regressor)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Evaluation Results:
# R2 Score(R2): -0.3522
# Mean Squared Error(MSE): 510.40
# Mean Absolute Error(MAE): 11.61

# %% [markdown]
# ### Bagging Regressor

# %%
# Load the trained Bagging Regressor model
model = joblib.load("/content/drive/MyDrive/SMAI_project/bagging_regressor_model.pkl")

# Make predictions
y_pred = model.predict(X_test)

# Evaluate
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f"Evaluation Results:")
print(f"R2 Score(R2): {r2:.4f}")
print(f"Mean Squared Error(MSE): {mse:.2f}")
print(f"Mean Absolute Error(MAE): {mae:.2f}")

# Plot predicted vs actual
plt.figure(figsize=(8, 6))
sns.scatterplot(x=y_test, y=y_pred, color='blue', s=40, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel("Actual Runs")
plt.ylabel("Predicted Runs")
plt.title("Predicted vs Actual Runs (Bagging Regressor)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Evaluation Results:
# R2 Score(R2): 0.9979
# Mean Squared Error(MSE): 0.78
# Mean Absolute Error(MAE): 0.12

# %% [markdown]
# ### Generalization

# %%
import joblib
from sklearn.linear_model import LinearRegression, BayesianRidge
from sklearn.neighbors import KNeighborsRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import (
    GradientBoostingRegressor,
    AdaBoostRegressor,
    BaggingRegressor,
    RandomForestRegressor,
)
from sklearn.model_selection import train_test_split

def build_model(df, player_country, opposition_country, venue_type):
    # Filter rows for the specified player_country, opposition_country, and venue_type
    player_df = df[
        (df["player_country"] == player_country) &
        (df["opposition_country"] == opposition_country) &
        (df["venue_type"] == venue_type)
    ]

    if player_df.empty:
        print("No data available for the given combination.")
        return None

    # Features and target variable
    X = player_df[["4s", "6s", "strike_rate", "BF", "year"]]
    y = player_df["runs"]

    # Split data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True)

    model_dict = {}

    models = {
        "KNeighborsRegressor": KNeighborsRegressor(),
        "GaussianProcessRegressor": GaussianProcessRegressor(),
        "DecisionTreeRegressor": DecisionTreeRegressor(),
        "GradientBoostingRegressor": GradientBoostingRegressor(),
        "AdaBoostRegressor": AdaBoostRegressor(),
        "BaggingRegressor": BaggingRegressor(),
        "RandomForestRegressor": RandomForestRegressor(),
    }

    for name, model in models.items():
        try:
            model.fit(X_train, y_train)
            score = model.score(X_test, y_test)
            model_dict[name] = {"model": model, "score": score}
        except Exception as e:
            print(f"Failed to train {name}: {e}")

    print("\nModel Scores (R2):")
    for model_name, model_info in model_dict.items():
        print(f"{model_name}: {model_info['score']:.4f}")

    # Select and save the best model
    best_model_name = max(model_dict, key=lambda k: model_dict[k]["score"])
    best_model = model_dict[best_model_name]["model"]
    best_score = model_dict[best_model_name]["score"]

    print(f"\nBest Model: {best_model_name} with score {best_score:.4f}")

    # Save best model to disk
    model_filename = f"best_model_{player_country}_{opposition_country}_{venue_type}.pkl"
    joblib.dump(best_model, model_filename)
    print(f"Best model saved as: {model_filename}")

    return model_dict, best_model, X_train, X_test, y_train, y_test, player_df

# %% [markdown]
# ### Plots

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data (replace with your actual model results)
model_names = ["RandomForest", "DecisionTree", "GradientBoosting","AdaBoost", "GaussianProcess", "Bagging"]
model_scores = [0.9978, 0.9969, 0.9960, 0.8595, -0.3522, 0.9979]  # Replace with your actual scores

# Plotting the R² scores
plt.figure(figsize=(10, 6))
plt.barh(model_names, model_scores, color='skyblue')
plt.xlabel('R² Score')
plt.title('Model Comparison by R² Score')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Example data (replace with your actual model results)
model_names = ["RandomForest", "DecisionTree", "GradientBoosting","AdaBoost", "GaussianProcess", "Bagging"]
model_scores = [0.12, 0.20, 0.81, 6.30, 11.61, 0.12]  # Replace with your actual scores

# Plotting the R² scores
plt.figure(figsize=(10, 6))
plt.barh(model_names, model_scores, color='lightgreen')
plt.xlabel('MAE Score')
plt.title('Model Comparison by MAE Score')
plt.show()
